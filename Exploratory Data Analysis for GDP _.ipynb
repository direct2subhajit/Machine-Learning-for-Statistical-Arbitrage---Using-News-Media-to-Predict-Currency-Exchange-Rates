# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

gdp = pd.read_csv (r'C:/Users/Shri/Downloads/GDP_YearWise.txt')
gdp.to_csv (r'C:/Users/Shri/Downloads/GDP_YearWise.csv', index=None)

# %%
gdp
# Out:
#       Unnamed: 0 Country Code Country Name  \
# 0           2412          CAN       Canada
# 1           2413          CAN       Canada
# 2           2414          CAN       Canada
# 3           2415          CAN       Canada
# 4           2416          CAN       Canada
# ...          ...          ...          ...
# 4426       47296          CHE  Switzerland
# 4427       47297          CHE  Switzerland
# 4428       47298          CHE  Switzerland
# 4429       47299          CHE  Switzerland
# 4430       47300          CHE  Switzerland
#
#                                      Subject  \
# 0     Gross Domestic Product (GDP); millions
# 1     Gross Domestic Product (GDP); millions
# 2     Gross Domestic Product (GDP); millions
# 3     Gross Domestic Product (GDP); millions
# 4     Gross Domestic Product (GDP); millions
# ...                                      ...
# 4426   Gross national income per hour worked
# 4427   Gross national income per hour worked
# 4428   Gross national income per hour worked
# 4429   Gross national income per hour worked
# 4430   Gross national income per hour worked
#
#                                 Measure  Year               Unit PowerCode  \
# 0     National currency, current prices  1981  National currency  Millions
# 1     National currency, current prices  1982  National currency  Millions
# 2     National currency, current prices  1983  National currency  Millions
# 3     National currency, current prices  1984  National currency  Millions
# 4     National currency, current prices  1985  National currency  Millions
# ...                                 ...   ...                ...       ...
# 4426  USD, current prices, current PPPs  2014         Percentage     Units
# 4427  USD, current prices, current PPPs  2015         Percentage     Units
# 4428  USD, current prices, current PPPs  2016         Percentage     Units
# 4429  USD, current prices, current PPPs  2017         Percentage     Units
# 4430  USD, current prices, current PPPs  2018         Percentage     Units
#
#               Value
# 0     368358.000000
# 1     388181.000000
# 2     421316.000000
# 3     461986.000000
# 4     500027.000000
# ...             ...
# 4426      67.017694
# 4427      69.574872
# 4428      69.891469
# 4429      71.011882
# 4430      75.039923
#
# [4431 rows x 9 columns]

# %%
# Checking the data type
gdp.dtypes
# Out:
# Unnamed: 0        int64
# Country Code     object
# Country Name     object
# Subject          object
# Measure          object
# Year              int64
# Unit             object
# PowerCode        object
# Value           float64
# dtype: object

# %%
gdp.columns
# Out:
# Index(['Unnamed: 0', 'Country Code', 'Country Name', 'Subject', 'Measure',
#        'Year', 'Unit', 'PowerCode', 'Value'],
#       dtype='object')

# %%
gdp.shape
# Out:
# (4431, 9)

# %%
duplicate_rows_gdp = gdp[gdp.duplicated()]
print("number of duplicate rows: ", duplicate_rows_gdp.shape)
# Out:
# number of duplicate rows:  (0, 9)

# %%
gdp.count()
# Out:
# Unnamed: 0      4431
# Country Code    4431
# Country Name    4431
# Subject         4431
# Measure         4431
# Year            4431
# Unit            4431
# PowerCode       4431
# Value           4431
# dtype: int64

# %% [markdown]
# ## Finding the null values

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4431 entries, 0 to 4430
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4431 non-null   int64
#  1   Country Code  4431 non-null   object
#  2   Country Name  4431 non-null   object
#  3   Subject       4431 non-null   object
#  4   Measure       4431 non-null   object
#  5   Year          4431 non-null   int64
#  6   Unit          4431 non-null   object
#  7   PowerCode     4431 non-null   object
#  8   Value         4431 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 207.8+ KB

# %% [markdown]
# ### Dropping the missing or null values

# %%
# Finding the null values.
print(gdp.isnull().sum())
# Out:
# Unnamed: 0      0
# Country Code    0
# Country Name    0
# Subject         0
# Measure         0
# Year            0
# Unit            0
# PowerCode       0
# Value           0
# dtype: int64

# %% [markdown]
# ### Detecting Outliers

# %%
gdp.boxplot(column=["Year"])
plt.show()

# %%
gdp.boxplot(column=["Value"])
plt.show()

# %%
gdp.describe()
# Out:
#          Unnamed: 0         Year         Value
# count   4431.000000  4431.000000  4.431000e+03
# mean   22298.106071  2000.531257  4.890599e+06
# std    12104.706178    11.182454  4.538891e+07
# min     2412.000000  1981.000000 -9.443420e+01
# 25%    11509.500000  1991.000000  4.752017e+01
# 50%    22176.000000  2001.000000  1.810000e+03
# 75%    32096.500000  2010.000000  6.516961e+04
# max    47300.000000  2019.000000  5.539620e+08

# %%
sns.pairplot(gdp,hue ='Year')

# %% [markdown]
# ### Countplot

# %%
gdp['Value'].value_counts()
# Out:
# 1.538000e+03    3
# 4.467141e+04    2
# 1.594899e+06    2
# 6.961457e+06    2
# 7.030002e+01    2
#                ..
# 1.251160e+05    1
# 1.142815e+02    1
# 7.258301e+02    1
# 3.987025e+04    1
# 3.287492e+04    1
# Name: Value, Length: 4406, dtype: int64

# %%
sns.countplot(x= gdp['Value'])

# %%
gdp['Unnamed: 0'].value_counts()
# Out:
# 20478    1
# 30104    1
# 47050    1
# 2676     1
# 31350    1
#         ..
# 11567    1
# 11563    1
# 11559    1
# 30463    1
# 32768    1
# Name: Unnamed: 0, Length: 4431, dtype: int64

# %%
gdp['Country Name'].value_counts()
# Out:
# United Kingdom    1014
# Canada            1014
# Switzerland       1013
# Japan             1013
# India              377
# Name: Country Name, dtype: int64

# %%
plt.figure(figsize=(12,10))
gdp['Country Name'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
gdp['Country Name'].value_counts()
# Out:
# United Kingdom    1014
# Canada            1014
# Switzerland       1013
# Japan             1013
# India              377
# Name: Country Name, dtype: int64

# %%
plt.figure(figsize=(12,10))
gdp['Country Code'].value_counts().plot.pie(autopct="%1.2f%%")
plt.show()

# %%
sns.countplot(x= gdp['Country Code'])

# %%
gdp.hist(figsize=(16, 20), bins=20, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0917CA10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x09F25ED0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x09F45FB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x09F64AF0>]],
#       dtype=object)

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(x="Year",y="Country Name",data=gdp)

# %% [markdown]
# ### Heat Maps

# %%
corr = gdp.corr()
gdp.corr()
# Out:
#             Unnamed: 0      Year     Value
# Unnamed: 0    1.000000  0.014485 -0.087706
# Year          0.014485  1.000000  0.019831
# Value        -0.087706  0.019831  1.000000

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= gdp.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#             Unnamed: 0      Year     Value
# Unnamed: 0    1.000000  0.014485 -0.087706
# Year          0.014485  1.000000  0.019831
# Value        -0.087706  0.019831  1.000000

# %% [markdown]
# ### Group plot

# %%
gdp.groupby('Country Name')[['Year','Value']].sum().plot(kind='bar',color=['yellow','blue'],figsize=(15,6))
plt.ylabel('Year and Value')
plt.legend()

# %%
gdp.groupby('Country Code')[['Year','Value']].sum().plot(kind='bar',color=['yellow','red'],figsize=(15,6))
plt.ylabel('Year and Value')
plt.legend()

# %% [markdown]
# ### scatter plot

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(gdp['Country Name'], gdp['Value'])
ax.set_xlabel('Country Name')
ax.set_ylabel('Value')
plt.show()

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(gdp['Subject'], gdp['PowerCode'])
ax.set_xlabel('Subject')
ax.set_ylabel('PowerCode')
plt.show()

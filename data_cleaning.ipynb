# %%
import pandas as pd
import numpy as np
df=pd.read_csv("API_PA.NUS.FCRF_DS2_en_csv_v2_1679468.csv",skiprows=4)
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code  \
# 0  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 1  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 2  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 3  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 4  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
#
#            1960          1961          1962          1963          1964  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.719656e+01  1.719656e+01  1.719656e+01  3.510964e+01  3.869226e+01
# 2  2.866844e-08  2.873486e-08  2.867844e-08  2.875203e-08  2.881978e-08
# 3           NaN           NaN           NaN           NaN           NaN
# ...

# %%
df.shape
# Out:
# (264, 66)

# %%
#droping columns that are not needed
df = df.drop(['Unnamed: 65','Indicator Name','Indicator Code'], axis=1)

# %%
df.shape
# Out:
# (264, 63)

# %%
#filling the columns having NaN with the previous column value
df.bfill(axis=1)
# Out:
#      Country Name Country Code         1960         1961         1962  \
# 0           Aruba          ABW         1.79         1.79         1.79
# 1     Afghanistan          AFG      17.1966      17.1966      17.1966
# 2          Angola          AGO  2.86684e-08  2.87349e-08  2.86784e-08
# 3         Albania          ALB      75.0325      75.0325      75.0325
# 4         Andorra          AND          NaN          NaN          NaN
# ..            ...          ...          ...          ...          ...
# 259        Kosovo          XKX      1.05756      1.05756      1.05756
# 260   Yemen, Rep.          YEM      12.0101      12.0101      12.0101
# 261  South Africa          ZAF     0.714286     0.714286     0.714286
# 262        Zambia          ZMB     0.714286     0.714286     0.714286
# 263      Zimbabwe          ZWE  0.000714286  0.000714286  0.000714286
#
#             1963         1964         1965         1966         1967  ...  \
# ...

# %%
#making a new dataframe containing required rows
df1 = df[(df['Country Name'].isin(['China','India','Great Britain','Canada','Japan','Switzerland']))]
df1
# Out:
#     Country Name Country Code        1960        1961        1962        1963  \
# 33        Canada          CAN    0.969767    1.013063    1.068769    1.078514
# 35   Switzerland          CHE    4.372950    4.372950    4.372950    4.372950
# 38         China          CHN    2.461809    2.461809    2.461809    2.461809
# 107        India          IND    4.761900    4.761900    4.761900    4.761900
# 117        Japan          JPN  360.000000  360.000000  360.000000  360.000000
#
#            1964        1965        1966        1967  ...       2011  \
# 33     1.078598    1.077984    1.077342    1.078710  ...   0.989258
# 35     4.372950    4.372950    4.372950    4.372950  ...   0.888042
# 38     2.461809    2.461809    2.461809    2.461809  ...   6.461461
# 107    4.761900    4.761900    6.359125    7.500000  ...  46.670467
# 117  360.000000  360.000000  360.000000  360.000000  ...  79.807020
#
#           2012       2013        2014        2015        2016        2017  \
# ...

# %%
#re-indexing
df1.reset_index(drop=True)
# Out:
#   Country Name Country Code        1960        1961        1962        1963  \
# 0       Canada          CAN    0.969767    1.013063    1.068769    1.078514
# 1  Switzerland          CHE    4.372950    4.372950    4.372950    4.372950
# 2        China          CHN    2.461809    2.461809    2.461809    2.461809
# 3        India          IND    4.761900    4.761900    4.761900    4.761900
# 4        Japan          JPN  360.000000  360.000000  360.000000  360.000000
#
#          1964        1965        1966        1967  ...       2011       2012  \
# 0    1.078598    1.077984    1.077342    1.078710  ...   0.989258   0.999365
# 1    4.372950    4.372950    4.372950    4.372950  ...   0.888042   0.937684
# 2    2.461809    2.461809    2.461809    2.461809  ...   6.461461   6.312333
# 3    4.761900    4.761900    6.359125    7.500000  ...  46.670467  53.437233
# 4  360.000000  360.000000  360.000000  360.000000  ...  79.807020  79.790455
#
# ...

# %%
df1.to_csv(r'cleaned_dataset.csv')
